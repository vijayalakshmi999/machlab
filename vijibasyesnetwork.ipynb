# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns
import sklearn as skl
import pandas as pd
import sys
#Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Hungarian_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
Switzerland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data'
np.set_printoptions(threshold=sys.maxsize) #see a whole array when we output it
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach','exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data
#HungarianHeartDisease = pd.read_csv(urlopen(Hungarian_data_URL), names = names) #gets Hungary data
#SwitzerlandHeartDisease = pd.read_csv(urlopen(Switzerland_data_URL), names = names) #gets Switzerland data
#datatemp = [ClevelandHeartDisease, HungarianHeartDisease,SwitzerlandHeartDisease] #combines all arrays into a list
#heartDisease = pd.concat(datatemp)#combines list into one array
heartDisease.head()
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']
heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
heartDisease.columns
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex','trestbps'), ('sex', 'trestbps'),('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
# print("CPD of {variable}:".format(variable=cpd.variable))
# print(cpd)
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# (age _|_ sex, exang)
# (age _|_ chol, thalach, restecg | heartdisease)
# (age _|_ sex, exang | fbs)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ chol, thalach, restecg | fbs, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, heartdisease)
# (age _|_ chol, thalach, restecg | exang, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ chol, thalach, restecg | sex, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ chol, restecg, thalach, heartdisease | fbs, trestbps)
# (age _|_ sex | fbs, exang)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, trestbps, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, sex, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, trestbps, heartdisease)
# (age _|_ thalach, restecg | chol, exang, heartdisease)
# (age _|_ restecg | chol, thalach, heartdisease)
# (age _|_ thalach, restecg | chol, sex, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, exang, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, sex, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, heartdisease)
# (age _|_ chol, restecg | thalach, exang, heartdisease)
# (age _|_ chol, thalach, restecg | sex, exang, heartdisease)
# (age _|_ chol, thalach | restecg, exang, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease)
# (age _|_ chol | restecg, thalach, heartdisease)
# (age _|_ chol, thalach | restecg, sex, heartdisease)
# (age _|_ restecg, thalach, heartdisease | fbs, chol, trestbps)
# (age _|_ chol, restecg, thalach, heartdisease | fbs, trestbps, exang)
# (age _|_ chol, restecg, heartdisease | fbs, trestbps, thalach)
# (age _|_ chol, restecg, thalach, heartdisease | fbs, trestbps, sex)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, restecg)
# (age _|_ thalach, restecg | fbs, chol, trestbps, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, exang, heartdisease)
# (age _|_ restecg | fbs, chol, thalach, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, sex, heartdisease)
# (age _|_ thalach | fbs, chol, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, trestbps, exang, heartdisease)
# (age _|_ chol, restecg | fbs, trestbps, thalach, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, trestbps, sex, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, trestbps, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, exang, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, sex, exang, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, exang, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, sex, heartdisease)
# (age _|_ chol | fbs, restecg, thalach, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, sex, heartdisease)
# (age _|_ thalach, restecg | chol, trestbps, exang, heartdisease)
# (age _|_ restecg | chol, trestbps, thalach, heartdisease)
# (age _|_ thalach, restecg | chol, trestbps, sex, heartdisease)
# (age _|_ thalach | chol, restecg, trestbps, heartdisease)
# (age _|_ restecg | chol, thalach, exang, heartdisease)
# (age _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (age _|_ thalach | chol, restecg, exang, heartdisease)
# (age _|_ restecg | chol, thalach, sex, heartdisease)
# (age _|_ thalach | chol, restecg, sex, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, exang, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, sex, exang, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, exang, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, sex, heartdisease)
# (age _|_ chol | restecg, trestbps, thalach, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, sex, heartdisease)
# (age _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (age _|_ chol | restecg, thalach, exang, heartdisease)
# (age _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (age _|_ chol | restecg, thalach, sex, heartdisease)
# (age _|_ thalach, heartdisease, restecg | fbs, chol, trestbps, exang)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, thalach)
# (age _|_ thalach, heartdisease, restecg | fbs, chol, trestbps, sex)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, restecg)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, thalach, exang)
# (age _|_ chol, thalach, heartdisease, restecg | fbs, trestbps, sex, exang)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, exang, restecg)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, thalach, sex)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, restecg)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, sex, restecg)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, trestbps, exang)
# (age _|_ restecg | heartdisease, fbs, chol, trestbps, thalach)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, trestbps, sex)
# (age _|_ thalach | heartdisease, fbs, chol, trestbps, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, exang, thalach)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, exang, sex)
# (age _|_ thalach | heartdisease, fbs, chol, exang, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, thalach, sex)
# (age _|_ thalach | heartdisease, fbs, chol, sex, restecg)
# (age _|_ chol, restecg | heartdisease, fbs, trestbps, exang, thalach)
# (age _|_ chol, thalach, restecg | heartdisease, fbs, trestbps, exang, sex)
# (age _|_ chol, thalach | heartdisease, fbs, trestbps, exang, restecg)
# (age _|_ chol, restecg | heartdisease, fbs, trestbps, thalach, sex)
# (age _|_ chol | heartdisease, fbs, trestbps, thalach, restecg)
# (age _|_ chol, thalach | heartdisease, fbs, trestbps, sex, restecg)
# (age _|_ chol, restecg | heartdisease, fbs, exang, thalach, sex)
# (age _|_ chol | heartdisease, fbs, exang, thalach, restecg)
# (age _|_ chol, thalach | heartdisease, fbs, exang, sex, restecg)
# (age _|_ chol | heartdisease, fbs, thalach, sex, restecg)
# (age _|_ restecg | heartdisease, chol, trestbps, exang, thalach)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, exang, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, exang, restecg)
# (age _|_ restecg | heartdisease, chol, trestbps, thalach, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, sex, restecg)
# (age _|_ restecg | heartdisease, chol, exang, thalach, sex)
# (age _|_ thalach | heartdisease, chol, exang, sex, restecg)
# (age _|_ chol, restecg | heartdisease, trestbps, exang, thalach, sex)
# (age _|_ chol | heartdisease, trestbps, exang, thalach, restecg)
# (age _|_ chol, thalach | heartdisease, trestbps, exang, sex, restecg)
# (age _|_ chol | heartdisease, trestbps, thalach, sex, restecg)
# (age _|_ chol | heartdisease, exang, thalach, sex, restecg)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, exang, thalach)
# (age _|_ thalach, heartdisease, restecg | fbs, chol, trestbps, exang, sex)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, exang, restecg)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, thalach, sex)
# (age _|_ heartdisease | fbs, chol, trestbps, thalach, restecg)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, sex, restecg)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, exang, thalach, sex)
# (age _|_ chol, heartdisease | fbs, trestbps, exang, thalach, restecg)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, exang, sex, restecg)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, sex, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, trestbps, exang, thalach)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, trestbps, exang, sex)
# (age _|_ thalach | heartdisease, fbs, chol, trestbps, exang, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, trestbps, thalach, sex)
# (age _|_ thalach | heartdisease, fbs, chol, trestbps, sex, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, exang, thalach, sex)
# (age _|_ thalach | heartdisease, fbs, chol, exang, sex, restecg)
# (age _|_ chol, restecg | heartdisease, fbs, trestbps, exang, thalach, sex)
# (age _|_ chol | heartdisease, fbs, trestbps, exang, thalach, restecg)
# (age _|_ chol, thalach | heartdisease, fbs, trestbps, exang, sex, restecg)
# (age _|_ chol | heartdisease, fbs, trestbps, thalach, sex, restecg)
# (age _|_ chol | heartdisease, fbs, exang, thalach, sex, restecg)
# (age _|_ restecg | heartdisease, chol, trestbps, exang, thalach, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, exang, sex, restecg)
# (age _|_ chol | heartdisease, trestbps, exang, thalach, sex, restecg)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, exang, thalach, sex)
# (age _|_ heartdisease | fbs, chol, trestbps, exang, thalach, restecg)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, exang, sex, restecg)
# (age _|_ heartdisease | fbs, chol, trestbps, thalach, sex, restecg)
# (age _|_ chol, heartdisease | fbs, trestbps, exang, thalach, sex, restecg)
# (age _|_ restecg | heartdisease, fbs, chol, trestbps, exang, thalach, sex)
# (age _|_ thalach | heartdisease, fbs, chol, trestbps, exang, sex, restecg)
# (age _|_ chol | heartdisease, fbs, trestbps, exang, thalach, sex, restecg)
# (age _|_ heartdisease | fbs, chol, trestbps, exang, thalach, sex, restecg)
# (trestbps _|_ chol, thalach, restecg | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, thalach, restecg | fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | age, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, age, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, sex, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, heartdisease)
# (trestbps _|_ restecg | chol, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ chol, thalach, restecg | age, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | sex, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | age, sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease)
# (trestbps _|_ chol | restecg, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, heartdisease)
# (trestbps _|_ fbs | age, sex, exang)
# (trestbps _|_ thalach, restecg | fbs, chol, exang, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, age, heartdisease)
# (trestbps _|_ restecg | fbs, chol, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, sex, heartdisease)
# (trestbps _|_ thalach | fbs, chol, restecg, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, age, exang, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, sex, exang, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, exang, heartdisease)
# (trestbps _|_ chol, restecg | fbs, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, age, sex, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, age, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, sex, heartdisease)
# (trestbps _|_ chol | fbs, restecg, thalach, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, exang, heartdisease)
# (trestbps _|_ restecg | chol, thalach, exang, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (trestbps _|_ thalach | chol, restecg, exang, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, sex, heartdisease)
# (trestbps _|_ thalach | chol, restecg, age, heartdisease)
# (trestbps _|_ restecg | chol, thalach, sex, heartdisease)
# (trestbps _|_ thalach | chol, restecg, sex, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | age, sex, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, exang, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (trestbps _|_ chol | restecg, thalach, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, sex, heartdisease)
# (trestbps _|_ chol | restecg, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, sex, heartdisease)
# (trestbps _|_ chol | restecg, thalach, sex, heartdisease)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol, exang, age)
# (trestbps _|_ restecg | heartdisease, fbs, chol, exang, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol, exang, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, exang, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, age, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol, age, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, age, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, thalach, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, sex, restecg)
# (trestbps _|_ chol, restecg | heartdisease, fbs, exang, age, thalach)
# (trestbps _|_ chol, thalach, restecg | heartdisease, fbs, exang, age, sex)
# (trestbps _|_ chol, thalach | heartdisease, fbs, exang, age, restecg)
# (trestbps _|_ chol, restecg | heartdisease, fbs, exang, thalach, sex)
# (trestbps _|_ chol | heartdisease, fbs, exang, thalach, restecg)
# (trestbps _|_ chol, thalach | heartdisease, fbs, exang, sex, restecg)
# (trestbps _|_ chol, restecg | heartdisease, fbs, age, thalach, sex)
# (trestbps _|_ chol | heartdisease, fbs, age, thalach, restecg)
# (trestbps _|_ chol, thalach | heartdisease, fbs, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, fbs, thalach, sex, restecg)
# (trestbps _|_ restecg | heartdisease, chol, exang, age, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, chol, exang, age, sex)
# (trestbps _|_ thalach | heartdisease, chol, exang, age, restecg)
# (trestbps _|_ restecg | heartdisease, chol, exang, thalach, sex)
# (trestbps _|_ thalach | heartdisease, chol, exang, sex, restecg)
# (trestbps _|_ restecg | heartdisease, chol, age, thalach, sex)
# (trestbps _|_ thalach | heartdisease, chol, age, sex, restecg)
# (trestbps _|_ chol, restecg | heartdisease, exang, age, thalach, sex)
# (trestbps _|_ chol | heartdisease, exang, age, thalach, restecg)
# (trestbps _|_ chol, thalach | heartdisease, exang, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, exang, thalach, sex, restecg)
# (trestbps _|_ chol | heartdisease, age, thalach, sex, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, exang, age, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol, exang, age, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, exang, age, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, exang, thalach, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, exang, sex, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, age, thalach, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, age, sex, restecg)
# (trestbps _|_ chol, restecg | heartdisease, fbs, exang, age, thalach, sex)
# (trestbps _|_ chol | heartdisease, fbs, exang, age, thalach, restecg)
# (trestbps _|_ chol, thalach | heartdisease, fbs, exang, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, fbs, exang, thalach, sex, restecg)
# (trestbps _|_ chol | heartdisease, fbs, age, thalach, sex, restecg)
# (trestbps _|_ restecg | heartdisease, chol, exang, age, thalach, sex)
# (trestbps _|_ thalach | heartdisease, chol, exang, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, exang, age, thalach, sex, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, exang, age, thalach, sex)
# (trestbps _|_ thalach | heartdisease, fbs, chol, exang, age, sex, restecg)
# (trestbps _|_ chol | heartdisease, fbs, exang, age, thalach, sex, restecg)
# (fbs _|_ sex, exang)
# (fbs _|_ chol, thalach, restecg | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ trestbps, sex, exang | age)
# (fbs _|_ exang | sex)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease)
# (fbs _|_ chol, thalach, restecg | age, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ thalach, restecg | chol, trestbps, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, heartdisease)
# (fbs _|_ restecg | chol, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, exang, heartdisease)
# (fbs _|_ thalach, sex, chol, exang, restecg | age, trestbps, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, heartdisease)
# (fbs _|_ chol, thalach, restecg | age, exang, heartdisease)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease)
# (fbs _|_ chol, thalach, restecg | sex, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | age, sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, age, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, heartdisease)
# (fbs _|_ sex, exang | age, chol, trestbps)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ sex, exang | age, trestbps, thalach)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ sex, exang | age, trestbps, restecg)
# (fbs _|_ trestbps | age, sex, exang)
# (fbs _|_ thalach, restecg | chol, trestbps, exang, heartdisease)
# (fbs _|_ thalach, sex, exang, restecg | age, chol, trestbps, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, trestbps, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, trestbps, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, exang, heartdisease)
# (fbs _|_ restecg | chol, thalach, exang, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, exang, heartdisease)
# (fbs _|_ thalach | chol, restecg, exang, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, age, heartdisease)
# (fbs _|_ restecg | chol, thalach, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, sex, heartdisease)
# (fbs _|_ chol, thalach, sex, restecg | age, trestbps, exang, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, exang, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, sex, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, exang, heartdisease)
# (fbs _|_ chol, sex, exang, restecg | age, trestbps, thalach, heartdisease)
# (fbs _|_ chol, thalach, exang, restecg | age, trestbps, sex, heartdisease)
# (fbs _|_ chol, thalach, sex, exang | age, restecg, trestbps, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, trestbps, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, sex, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, exang, heartdisease)
# (fbs _|_ chol, thalach, restecg | age, sex, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, age, exang, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, exang, heartdisease)
# (fbs _|_ chol | restecg, thalach, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, age, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, age, sex, heartdisease)
# (fbs _|_ chol | restecg, thalach, sex, heartdisease)
# (fbs _|_ sex | age, chol, trestbps, exang)
# (fbs _|_ sex, exang | age, chol, trestbps, thalach)
# (fbs _|_ exang | age, chol, trestbps, sex)
# (fbs _|_ sex, exang | age, chol, trestbps, restecg)
# (fbs _|_ sex | age, trestbps, thalach, exang)
# (fbs _|_ sex | age, trestbps, exang, restecg)
# (fbs _|_ exang | age, trestbps, thalach, sex)
# (fbs _|_ sex, exang | age, trestbps, thalach, restecg)
# (fbs _|_ exang | age, trestbps, sex, restecg)
# (fbs _|_ thalach, sex, restecg | heartdisease, chol, trestbps, exang, age)
# (fbs _|_ restecg | heartdisease, chol, trestbps, exang, thalach)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps, exang, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, exang, restecg)
# (fbs _|_ sex, exang, restecg | heartdisease, chol, trestbps, age, thalach)
# (fbs _|_ thalach, exang, restecg | heartdisease, chol, trestbps, age, sex)
# (fbs _|_ thalach, sex, exang | heartdisease, chol, trestbps, age, restecg)
# (fbs _|_ restecg | heartdisease, chol, trestbps, thalach, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, sex, restecg)
# (fbs _|_ restecg | heartdisease, chol, exang, age, thalach)
# (fbs _|_ thalach, restecg | heartdisease, chol, exang, age, sex)
# (fbs _|_ thalach | heartdisease, chol, exang, age, restecg)
# (fbs _|_ restecg | heartdisease, chol, exang, thalach, sex)
# (fbs _|_ thalach | heartdisease, chol, exang, sex, restecg)
# (fbs _|_ restecg | heartdisease, chol, age, thalach, sex)
# (fbs _|_ thalach | heartdisease, chol, age, sex, restecg)
# (fbs _|_ chol, sex, restecg | heartdisease, trestbps, exang, age, thalach)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps, exang, age, sex)
# (fbs _|_ chol, thalach, sex | heartdisease, trestbps, exang, age, restecg)
# (fbs _|_ chol, restecg | heartdisease, trestbps, exang, thalach, sex)
# (fbs _|_ chol | heartdisease, trestbps, exang, thalach, restecg)
# (fbs _|_ chol, thalach | heartdisease, trestbps, exang, sex, restecg)
# (fbs _|_ chol, exang, restecg | heartdisease, trestbps, age, thalach, sex)
# (fbs _|_ chol, sex, exang | heartdisease, trestbps, age, thalach, restecg)
# (fbs _|_ chol, thalach, exang | heartdisease, trestbps, age, sex, restecg)
# (fbs _|_ chol | heartdisease, trestbps, thalach, sex, restecg)
# (fbs _|_ chol, restecg | heartdisease, exang, age, thalach, sex)
# (fbs _|_ chol | heartdisease, exang, age, thalach, restecg)
# (fbs _|_ chol, thalach | heartdisease, exang, age, sex, restecg)
# (fbs _|_ chol | heartdisease, exang, thalach, sex, restecg)
# (fbs _|_ chol | heartdisease, age, thalach, sex, restecg)
# (fbs _|_ sex | chol, trestbps, exang, age, thalach)
# (fbs _|_ sex | chol, trestbps, exang, age, restecg)
# (fbs _|_ exang | chol, trestbps, age, thalach, sex)
# (fbs _|_ sex, exang | chol, trestbps, age, thalach, restecg)
# (fbs _|_ exang | chol, trestbps, age, sex, restecg)
# (fbs _|_ sex | trestbps, exang, age, thalach, restecg)
# (fbs _|_ exang | trestbps, age, thalach, sex, restecg)
# (fbs _|_ sex, restecg | heartdisease, chol, trestbps, exang, age, thalach)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps, exang, age, sex)
# (fbs _|_ thalach, sex | heartdisease, chol, trestbps, exang, age, restecg)
# (fbs _|_ restecg | heartdisease, chol, trestbps, exang, thalach, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, exang, sex, restecg)
# (fbs _|_ exang, restecg | heartdisease, chol, trestbps, age, thalach, sex)
# (fbs _|_ sex, exang | heartdisease, chol, trestbps, age, thalach, restecg)
# (fbs _|_ thalach, exang | heartdisease, chol, trestbps, age, sex, restecg)
# (fbs _|_ restecg | heartdisease, chol, exang, age, thalach, sex)
# (fbs _|_ thalach | heartdisease, chol, exang, age, sex, restecg)
# (fbs _|_ chol, restecg | heartdisease, trestbps, exang, age, thalach, sex)
# (fbs _|_ chol, sex | heartdisease, trestbps, exang, age, thalach, restecg)
# (fbs _|_ chol, thalach | heartdisease, trestbps, exang, age, sex, restecg)
# (fbs _|_ chol | heartdisease, trestbps, exang, thalach, sex, restecg)
# (fbs _|_ chol, exang | heartdisease, trestbps, age, thalach, sex, restecg)
# (fbs _|_ chol | heartdisease, exang, age, thalach, sex, restecg)
# (fbs _|_ sex | chol, trestbps, exang, age, thalach, restecg)
# (fbs _|_ exang | chol, trestbps, age, thalach, sex, restecg)
# (fbs _|_ restecg | heartdisease, chol, trestbps, exang, age, thalach, sex)
# (fbs _|_ sex | heartdisease, chol, trestbps, exang, age, thalach, restecg)
# (fbs _|_ thalach | heartdisease, chol, trestbps, exang, age, sex, restecg)
# (fbs _|_ exang | heartdisease, chol, trestbps, age, thalach, sex, restecg)
# (fbs _|_ chol | heartdisease, trestbps, exang, age, thalach, sex, restecg)
# (sex _|_ fbs, age, exang)
# (sex _|_ chol, thalach, restecg | heartdisease)
# (sex _|_ age, exang | fbs)
# (sex _|_ fbs, age | exang)
# (sex _|_ fbs, exang | age)
# (sex _|_ chol, thalach, restecg | fbs, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ chol, thalach, restecg | trestbps, heartdisease)
# (sex _|_ chol, thalach, restecg | exang, heartdisease)
# (sex _|_ chol, thalach, restecg | age, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ chol, restecg, thalach, heartdisease | fbs, trestbps)
# (sex _|_ age | fbs, exang)
# (sex _|_ exang | fbs, age)
# (sex _|_ thalach, heartdisease, fbs, chol, restecg | age, trestbps)
# (sex _|_ fbs | age, exang)
# (sex _|_ thalach, restecg | fbs, chol, heartdisease)
# (sex _|_ chol, thalach, restecg | fbs, trestbps, heartdisease)
# (sex _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (sex _|_ chol, thalach, restecg | fbs, age, heartdisease)
# (sex _|_ chol, restecg | fbs, thalach, heartdisease)
# (sex _|_ chol, thalach | fbs, restecg, heartdisease)
# (sex _|_ thalach, restecg | chol, trestbps, heartdisease)
# (sex _|_ thalach, restecg | chol, exang, heartdisease)
# (sex _|_ thalach, restecg | chol, age, heartdisease)
# (sex _|_ restecg | chol, thalach, heartdisease)
# ...
# (thalach _|_ chol, age, exang | heartdisease, fbs, trestbps, sex, restecg)
# (thalach _|_ chol, trestbps, restecg | heartdisease, fbs, exang, age, sex)
# (thalach _|_ chol, trestbps, sex | heartdisease, fbs, exang, age, restecg)
# (thalach _|_ chol, age, trestbps | heartdisease, fbs, exang, sex, restecg)
# (thalach _|_ chol, trestbps, exang | heartdisease, fbs, age, sex, restecg)
# (thalach _|_ fbs, sex, restecg | heartdisease, chol, trestbps, exang, age)
# (thalach _|_ fbs, age, restecg | heartdisease, chol, trestbps, exang, sex)
# (thalach _|_ fbs, age, sex | heartdisease, chol, trestbps, exang, restecg)
# (thalach _|_ fbs, exang, restecg | heartdisease, chol, trestbps, age, sex)
# (thalach _|_ fbs, sex, exang | heartdisease, chol, trestbps, age, restecg)
# (thalach _|_ fbs, age, exang | heartdisease, chol, trestbps, sex, restecg)
# (thalach _|_ fbs, trestbps, restecg | heartdisease, chol, exang, age, sex)
# (thalach _|_ fbs, trestbps, sex | heartdisease, chol, exang, age, restecg)
# (thalach _|_ fbs, trestbps, age | heartdisease, chol, exang, sex, restecg)
# (thalach _|_ fbs, trestbps, exang | heartdisease, chol, age, sex, restecg)
# (thalach _|_ fbs, chol, restecg | heartdisease, trestbps, exang, age, sex)
# (thalach _|_ fbs, chol, sex | heartdisease, trestbps, exang, age, restecg)
# (thalach _|_ fbs, chol, age | heartdisease, trestbps, exang, sex, restecg)
# (thalach _|_ fbs, chol, exang | heartdisease, trestbps, age, sex, restecg)
# (thalach _|_ fbs, chol, trestbps | heartdisease, exang, age, sex, restecg)
# (thalach _|_ sex | fbs, chol, trestbps, exang, age)
# (thalach _|_ age | fbs, chol, trestbps, exang, sex)
# (thalach _|_ age, sex | fbs, chol, trestbps, exang, restecg)
# (thalach _|_ exang | fbs, chol, trestbps, age, sex)
# (thalach _|_ sex, exang | fbs, chol, trestbps, age, restecg)
# (thalach _|_ age, exang | fbs, chol, trestbps, sex, restecg)
# (thalach _|_ sex | fbs, trestbps, exang, age, restecg)
# (thalach _|_ age | fbs, trestbps, exang, sex, restecg)
# (thalach _|_ exang | fbs, trestbps, age, sex, restecg)
# (thalach _|_ sex | chol, trestbps, exang, age, restecg)
# (thalach _|_ exang | chol, trestbps, age, sex, restecg)
# (thalach _|_ sex, restecg | heartdisease, fbs, chol, trestbps, exang, age)
# (thalach _|_ age, restecg | heartdisease, fbs, chol, trestbps, exang, sex)
# (thalach _|_ age, sex | heartdisease, fbs, chol, trestbps, exang, restecg)
# (thalach _|_ exang, restecg | heartdisease, fbs, chol, trestbps, age, sex)
# (thalach _|_ sex, exang | heartdisease, fbs, chol, trestbps, age, restecg)
# (thalach _|_ age, exang | heartdisease, fbs, chol, trestbps, sex, restecg)
# (thalach _|_ trestbps, restecg | heartdisease, fbs, chol, exang, age, sex)
# (thalach _|_ trestbps, sex | heartdisease, fbs, chol, exang, age, restecg)
# (thalach _|_ trestbps, age | heartdisease, fbs, chol, exang, sex, restecg)
# (thalach _|_ trestbps, exang | heartdisease, fbs, chol, age, sex, restecg)
# (thalach _|_ chol, restecg | heartdisease, fbs, trestbps, exang, age, sex)
# (thalach _|_ chol, sex | heartdisease, fbs, trestbps, exang, age, restecg)
# (thalach _|_ chol, age | heartdisease, fbs, trestbps, exang, sex, restecg)
# (thalach _|_ chol, exang | heartdisease, fbs, trestbps, age, sex, restecg)
# (thalach _|_ chol, trestbps | heartdisease, fbs, exang, age, sex, restecg)
# (thalach _|_ fbs, restecg | heartdisease, chol, trestbps, exang, age, sex)
# (thalach _|_ fbs, sex | heartdisease, chol, trestbps, exang, age, restecg)
# (thalach _|_ fbs, age | heartdisease, chol, trestbps, exang, sex, restecg)
# (thalach _|_ fbs, exang | heartdisease, chol, trestbps, age, sex, restecg)
# (thalach _|_ fbs, trestbps | heartdisease, chol, exang, age, sex, restecg)
# (thalach _|_ fbs, chol | heartdisease, trestbps, exang, age, sex, restecg)
# (thalach _|_ sex | fbs, chol, trestbps, exang, age, restecg)
# (thalach _|_ age | fbs, chol, trestbps, exang, sex, restecg)
# (thalach _|_ exang | fbs, chol, trestbps, age, sex, restecg)
# (thalach _|_ restecg | heartdisease, fbs, chol, trestbps, exang, age, sex)
# (thalach _|_ sex | heartdisease, fbs, chol, trestbps, exang, age, restecg)
# (thalach _|_ age | heartdisease, fbs, chol, trestbps, exang, sex, restecg)
# (thalach _|_ exang | heartdisease, fbs, chol, trestbps, age, sex, restecg)
# (thalach _|_ trestbps | heartdisease, fbs, chol, exang, age, sex, restecg)
# (thalach _|_ chol | heartdisease, fbs, trestbps, exang, age, sex, restecg)
# (thalach _|_ fbs | heartdisease, chol, trestbps, exang, age, sex, restecg)
# (chol _|_ age, thalach, sex, fbs, trestbps, exang, restecg | heartdisease)
# (chol _|_ age, thalach, sex, trestbps, exang, restecg | fbs, heartdisease)
# (chol _|_ age, thalach, sex, fbs, exang, restecg | trestbps, heartdisease)
# (chol _|_ age, thalach, sex, fbs, trestbps, restecg | exang, heartdisease)
# (chol _|_ thalach, sex, fbs, trestbps, exang, restecg | age, heartdisease)
# (chol _|_ age, sex, fbs, trestbps, exang, restecg | thalach, heartdisease)
# (chol _|_ age, thalach, fbs, trestbps, exang, restecg | sex, heartdisease)
# (chol _|_ age, thalach, sex, fbs, trestbps, exang | restecg, heartdisease)
# (chol _|_ age, sex, exang | fbs, trestbps)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ age, thalach, sex, exang, restecg | fbs, trestbps, heartdisease)
# (chol _|_ age, thalach, sex, trestbps, restecg | fbs, exang, heartdisease)
# (chol _|_ thalach, sex, trestbps, exang, restecg | fbs, age, heartdisease)
# (chol _|_ age, sex, trestbps, exang, restecg | fbs, thalach, heartdisease)
# (chol _|_ age, thalach, trestbps, exang, restecg | fbs, sex, heartdisease)
# (chol _|_ age, thalach, sex, trestbps, exang | fbs, restecg, heartdisease)
# (chol _|_ age, thalach, sex, fbs, restecg | trestbps, exang, heartdisease)
# (chol _|_ thalach, sex, fbs, exang, restecg | age, trestbps, heartdisease)
# (chol _|_ age, sex, fbs, exang, restecg | trestbps, thalach, heartdisease)
# (chol _|_ age, thalach, fbs, exang, restecg | trestbps, sex, heartdisease)
# (chol _|_ age, thalach, sex, fbs, exang | restecg, trestbps, heartdisease)
# (chol _|_ thalach, sex, fbs, trestbps, restecg | age, exang, heartdisease)
# (chol _|_ age, sex, fbs, trestbps, restecg | thalach, exang, heartdisease)
# (chol _|_ age, thalach, fbs, trestbps, restecg | sex, exang, heartdisease)
# (chol _|_ age, thalach, sex, fbs, trestbps | restecg, exang, heartdisease)
# (chol _|_ sex, fbs, trestbps, exang, restecg | age, thalach, heartdisease)
# (chol _|_ thalach, fbs, trestbps, exang, restecg | age, sex, heartdisease)
# (chol _|_ thalach, sex, fbs, trestbps, exang | restecg, age, heartdisease)
# (chol _|_ age, fbs, trestbps, exang, restecg | thalach, sex, heartdisease)
# (chol _|_ age, sex, fbs, trestbps, exang | restecg, thalach, heartdisease)
# (chol _|_ age, thalach, fbs, trestbps, exang | restecg, sex, heartdisease)
# (chol _|_ age, sex | fbs, trestbps, exang)
# (chol _|_ sex, exang | fbs, trestbps, age)
# (chol _|_ age, sex, exang | fbs, trestbps, thalach)
# (chol _|_ age, exang | fbs, trestbps, sex)
# (chol _|_ age, sex, exang | fbs, trestbps, restecg)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ sex, exang | age, trestbps, thalach)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ sex, exang | age, trestbps, restecg)
# (chol _|_ age, thalach, sex, restecg | fbs, trestbps, exang, heartdisease)
# (chol _|_ thalach, sex, exang, restecg | fbs, trestbps, age, heartdisease)
# (chol _|_ age, sex, exang, restecg | fbs, trestbps, thalach, heartdisease)
# (chol _|_ age, thalach, exang, restecg | fbs, trestbps, sex, heartdisease)
# (chol _|_ age, thalach, sex, exang | fbs, restecg, trestbps, heartdisease)
# (chol _|_ trestbps, thalach, sex, restecg | fbs, age, exang, heartdisease)
# (chol _|_ trestbps, age, sex, restecg | fbs, thalach, exang, heartdisease)
# (chol _|_ trestbps, age, thalach, restecg | fbs, sex, exang, heartdisease)
# (chol _|_ trestbps, age, thalach, sex | fbs, restecg, exang, heartdisease)
# (chol _|_ trestbps, sex, exang, restecg | fbs, age, thalach, heartdisease)
# (chol _|_ trestbps, thalach, exang, restecg | fbs, age, sex, heartdisease)
# (chol _|_ trestbps, thalach, sex, exang | fbs, restecg, age, heartdisease)
# (chol _|_ trestbps, age, exang, restecg | fbs, thalach, sex, heartdisease)
# (chol _|_ trestbps, age, sex, exang | fbs, restecg, thalach, heartdisease)
# (chol _|_ trestbps, age, thalach, exang | fbs, restecg, sex, heartdisease)
# (chol _|_ fbs, thalach, sex, restecg | age, trestbps, exang, heartdisease)
# (chol _|_ fbs, age, sex, restecg | trestbps, thalach, exang, heartdisease)
# (chol _|_ fbs, age, thalach, restecg | trestbps, sex, exang, heartdisease)
# (chol _|_ fbs, age, thalach, sex | restecg, trestbps, exang, heartdisease)
# (chol _|_ fbs, sex, exang, restecg | age, trestbps, thalach, heartdisease)
# (chol _|_ fbs, thalach, exang, restecg | age, trestbps, sex, heartdisease)
# (chol _|_ fbs, thalach, sex, exang | age, restecg, trestbps, heartdisease)
# (chol _|_ fbs, age, exang, restecg | trestbps, thalach, sex, heartdisease)
# (chol _|_ fbs, age, sex, exang | restecg, trestbps, thalach, heartdisease)
# (chol _|_ fbs, age, thalach, exang | restecg, trestbps, sex, heartdisease)
# (chol _|_ fbs, trestbps, sex, restecg | age, thalach, exang, heartdisease)
# (chol _|_ fbs, trestbps, thalach, restecg | age, sex, exang, heartdisease)
# (chol _|_ fbs, trestbps, thalach, sex | restecg, age, exang, heartdisease)
# (chol _|_ fbs, trestbps, age, restecg | thalach, sex, exang, heartdisease)
# (chol _|_ fbs, trestbps, age, sex | restecg, thalach, exang, heartdisease)
# (chol _|_ fbs, age, trestbps, thalach | restecg, sex, exang, heartdisease)
# (chol _|_ fbs, trestbps, exang, restecg | age, thalach, sex, heartdisease)
# (chol _|_ fbs, trestbps, sex, exang | restecg, age, thalach, heartdisease)
# (chol _|_ fbs, trestbps, thalach, exang | restecg, age, sex, heartdisease)
# (chol _|_ fbs, trestbps, age, exang | restecg, thalach, sex, heartdisease)
# (chol _|_ sex | fbs, trestbps, age, exang)
# (chol _|_ age, sex | fbs, trestbps, thalach, exang)
# (chol _|_ age | fbs, trestbps, sex, exang)
# (chol _|_ age, sex | fbs, trestbps, exang, restecg)
# (chol _|_ sex, exang | fbs, thalach, trestbps, age)
# (chol _|_ exang | fbs, trestbps, age, sex)
# (chol _|_ sex, exang | fbs, trestbps, age, restecg)
# (chol _|_ age, exang | fbs, trestbps, thalach, sex)
# (chol _|_ age, sex, exang | fbs, trestbps, thalach, restecg)
# (chol _|_ age, exang | fbs, trestbps, sex, restecg)
# (chol _|_ sex | age, trestbps, thalach, exang)
# (chol _|_ sex | age, trestbps, exang, restecg)
# (chol _|_ exang | age, trestbps, thalach, sex)
# (chol _|_ sex, exang | age, trestbps, thalach, restecg)
# (chol _|_ exang | age, trestbps, sex, restecg)
# (chol _|_ thalach, sex, restecg | heartdisease, fbs, trestbps, exang, age)
# (chol _|_ age, sex, restecg | heartdisease, fbs, trestbps, exang, thalach)
# (chol _|_ age, thalach, restecg | heartdisease, fbs, trestbps, exang, sex)
# (chol _|_ age, thalach, sex | heartdisease, fbs, trestbps, exang, restecg)
# (chol _|_ sex, exang, restecg | heartdisease, fbs, trestbps, age, thalach)
# (chol _|_ thalach, exang, restecg | heartdisease, fbs, trestbps, age, sex)
# (chol _|_ thalach, sex, exang | heartdisease, fbs, trestbps, age, restecg)
# (chol _|_ age, exang, restecg | heartdisease, fbs, trestbps, thalach, sex)
# (chol _|_ age, sex, exang | heartdisease, fbs, trestbps, thalach, restecg)
# (chol _|_ age, thalach, exang | heartdisease, fbs, trestbps, sex, restecg)
# (chol _|_ trestbps, sex, restecg | heartdisease, fbs, exang, age, thalach)
# (chol _|_ trestbps, thalach, restecg | heartdisease, fbs, exang, age, sex)
# (chol _|_ trestbps, thalach, sex | heartdisease, fbs, exang, age, restecg)
# (chol _|_ trestbps, age, restecg | heartdisease, fbs, exang, thalach, sex)
# (chol _|_ trestbps, age, sex | heartdisease, fbs, exang, thalach, restecg)
# (chol _|_ trestbps, age, thalach | heartdisease, fbs, exang, sex, restecg)
# (chol _|_ trestbps, exang, restecg | heartdisease, fbs, age, thalach, sex)
# (chol _|_ trestbps, sex, exang | heartdisease, fbs, age, thalach, restecg)
# (chol _|_ trestbps, thalach, exang | heartdisease, fbs, age, sex, restecg)
# (chol _|_ trestbps, age, exang | heartdisease, fbs, thalach, sex, restecg)
# (chol _|_ fbs, sex, restecg | heartdisease, trestbps, exang, age, thalach)
# (chol _|_ fbs, thalach, restecg | heartdisease, trestbps, exang, age, sex)
# (chol _|_ fbs, thalach, sex | heartdisease, trestbps, exang, age, restecg)
# (chol _|_ fbs, age, restecg | heartdisease, trestbps, exang, thalach, sex)
# (chol _|_ fbs, age, sex | heartdisease, trestbps, exang, thalach, restecg)
# (chol _|_ fbs, age, thalach | heartdisease, trestbps, exang, sex, restecg)
# (chol _|_ fbs, exang, restecg | heartdisease, trestbps, age, thalach, sex)
# (chol _|_ fbs, sex, exang | heartdisease, trestbps, age, thalach, restecg)
# (chol _|_ fbs, thalach, exang | heartdisease, trestbps, age, sex, restecg)
# (chol _|_ fbs, age, exang | heartdisease, trestbps, thalach, sex, restecg)
# (chol _|_ fbs, trestbps, restecg | heartdisease, exang, age, thalach, sex)
# (chol _|_ fbs, trestbps, sex | heartdisease, exang, age, thalach, restecg)
# (chol _|_ fbs, trestbps, thalach | heartdisease, exang, age, sex, restecg)
# (chol _|_ fbs, trestbps, age | heartdisease, exang, thalach, sex, restecg)
# (chol _|_ fbs, trestbps, exang | heartdisease, age, thalach, sex, restecg)
# (chol _|_ sex | fbs, trestbps, exang, age, thalach)
# (chol _|_ sex | fbs, trestbps, exang, age, restecg)
# (chol _|_ age | fbs, trestbps, exang, thalach, sex)
# (chol _|_ age, sex | fbs, trestbps, exang, thalach, restecg)
# (chol _|_ age | fbs, trestbps, exang, sex, restecg)
# (chol _|_ exang | fbs, trestbps, age, thalach, sex)
# (chol _|_ sex, exang | fbs, trestbps, age, thalach, restecg)
# (chol _|_ exang | fbs, trestbps, age, sex, restecg)
# (chol _|_ age, exang | fbs, trestbps, thalach, sex, restecg)
# (chol _|_ sex | trestbps, exang, age, thalach, restecg)
# (chol _|_ exang | trestbps, age, thalach, sex, restecg)
# (chol _|_ sex, restecg | heartdisease, fbs, trestbps, exang, age, thalach)
# (chol _|_ thalach, restecg | heartdisease, fbs, trestbps, exang, age, sex)
# (chol _|_ thalach, sex | heartdisease, fbs, trestbps, exang, age, restecg)
# (chol _|_ age, restecg | heartdisease, fbs, trestbps, exang, thalach, sex)
# (chol _|_ age, sex | heartdisease, fbs, trestbps, exang, thalach, restecg)
# (chol _|_ age, thalach | heartdisease, fbs, trestbps, exang, sex, restecg)
# (chol _|_ exang, restecg | heartdisease, fbs, trestbps, age, thalach, sex)
# (chol _|_ sex, exang | heartdisease, fbs, trestbps, age, thalach, restecg)
# (chol _|_ thalach, exang | heartdisease, fbs, trestbps, age, sex, restecg)
# (chol _|_ age, exang | heartdisease, fbs, trestbps, thalach, sex, restecg)
# (chol _|_ trestbps, restecg | heartdisease, fbs, exang, age, thalach, sex)
# (chol _|_ trestbps, sex | heartdisease, fbs, exang, age, thalach, restecg)
# (chol _|_ trestbps, thalach | heartdisease, fbs, exang, age, sex, restecg)
# (chol _|_ trestbps, age | heartdisease, fbs, exang, thalach, sex, restecg)
# (chol _|_ trestbps, exang | heartdisease, fbs, age, thalach, sex, restecg)
# (chol _|_ fbs, restecg | heartdisease, trestbps, exang, age, thalach, sex)
# (chol _|_ fbs, sex | heartdisease, trestbps, exang, age, thalach, restecg)
# (chol _|_ fbs, thalach | heartdisease, trestbps, exang, age, sex, restecg)
# (chol _|_ fbs, age | heartdisease, trestbps, exang, thalach, sex, restecg)
# (chol _|_ fbs, exang | heartdisease, trestbps, age, thalach, sex, restecg)
# (chol _|_ fbs, trestbps | heartdisease, exang, age, thalach, sex, restecg)
# (chol _|_ sex | fbs, trestbps, exang, age, thalach, restecg)
# (chol _|_ age | fbs, trestbps, exang, thalach, sex, restecg)
# (chol _|_ exang | fbs, trestbps, age, thalach, sex, restecg)
# (chol _|_ restecg | heartdisease, fbs, trestbps, exang, age, thalach, sex)
# (chol _|_ sex | heartdisease, fbs, trestbps, exang, age, thalach, restecg)
# (chol _|_ thalach | heartdisease, fbs, trestbps, exang, age, sex, restecg)
# (chol _|_ age | heartdisease, fbs, trestbps, exang, thalach, sex, restecg)
# (chol _|_ exang | heartdisease, fbs, trestbps, age, thalach, sex, restecg)
# (chol _|_ trestbps | heartdisease, fbs, exang, age, thalach, sex, restecg)
# (chol _|_ fbs | heartdisease, trestbps, exang, age, thalach, sex, restecg)
